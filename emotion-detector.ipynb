# %% [markdown]
# # ( [Data Link](https://www.kaggle.com/datasets/ananthu017/emotion-detection-fer) )

# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import keras
from keras.preprocessing import image
from keras.models import Sequential
from keras.layers import Conv2D, MaxPool2D, Flatten,Dense,Dropout,BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import cv2
from tensorflow.keras.applications import VGG16, InceptionResNetV2
from keras import regularizers
from tensorflow.keras.optimizers import Adam,RMSprop,SGD,Adamax

# %%
train_dir = "../input/emotion-detection-fer/train"
test_dir = "../input/emotion-detection-fer/test"

# %%
img_size = 48

# %%
train_datagen = ImageDataGenerator(#rotation_range = 180,
                                         width_shift_range = 0.1,
                                         height_shift_range = 0.1,
                                         horizontal_flip = True,
                                         rescale = 1./255,
                                         #zoom_range = 0.2,
                                         validation_split = 0.2
                                        )
validation_datagen = ImageDataGenerator(rescale = 1./255,
                                         validation_split = 0.2)

# %%
train_generator = train_datagen.flow_from_directory(directory = train_dir,
                                                    target_size = (img_size,img_size),
                                                    batch_size = 64,
                                                    color_mode = "grayscale",
                                                    class_mode = "categorical",
                                                    subset = "training"
                                                   )
validation_generator = validation_datagen.flow_from_directory( directory = test_dir,
                                                              target_size = (img_size,img_size),
                                                              batch_size = 64,
                                                              color_mode = "grayscale",
                                                              class_mode = "categorical",
                                                              subset = "validation"
                                                             )
# Out:
# Found 22968 images belonging to 7 classes.
# Found 1432 images belonging to 7 classes.

# %%
model= tf.keras.models.Sequential()
model.add(Conv2D(32, kernel_size=(3, 3), padding='same', activation='relu', input_shape=(48, 48,1)))
model.add(Conv2D(64,(3,3), padding='same', activation='relu' ))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(128,(5,5), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
    
model.add(Conv2D(512,(3,3), padding='same', activation='relu', kernel_regularizer=regularizers.l2(0.01)))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(512,(3,3), padding='same', activation='relu', kernel_regularizer=regularizers.l2(0.01)))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten()) 
model.add(Dense(256,activation = 'relu'))
model.add(BatchNormalization())
model.add(Dropout(0.25))
    
model.add(Dense(512,activation = 'relu'))
model.add(BatchNormalization())
model.add(Dropout(0.25))

model.add(Dense(7, activation='softmax'))

model.compile(
    optimizer = Adam(lr=0.0001), 
    loss='categorical_crossentropy', 
    metrics=['accuracy']
  )

# %%
epochs = 60
batch_size = 64

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 48, 48, 32)        320
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 48, 48, 64)        18496
# _________________________________________________________________
# batch_normalization (BatchNo (None, 48, 48, 64)        256
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 24, 24, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 24, 24, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 24, 24, 128)       204928
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 24, 24, 128)       512
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 12, 12, 128)       0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 12, 12, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 12, 12, 512)       590336
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 12, 12, 512)       2048
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 6, 6, 512)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 6, 6, 512)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 6, 6, 512)         2359808
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 6, 6, 512)         2048
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 3, 3, 512)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 3, 3, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 4608)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               1179904
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               131584
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 7)                 3591
# =================================================================
# Total params: 4,496,903
# Trainable params: 4,492,935
# Non-trainable params: 3,968
# _________________________________________________________________

# %%
history = model.fit(x=train_generator, epochs=epochs, validation_data=validation_generator)
# Out:
# Epoch 1/60
# 359/359 [==============================] - 80s 212ms/step - loss: 9.5989 - accuracy: 0.1835 - val_loss: 8.9823 - val_accuracy: 0.1418
# Epoch 2/60
# 359/359 [==============================] - 26s 74ms/step - loss: 8.5268 - accuracy: 0.2217 - val_loss: 7.7084 - val_accuracy: 0.2472
# Epoch 3/60
# 359/359 [==============================] - 29s 80ms/step - loss: 7.5436 - accuracy: 0.2455 - val_loss: 6.5895 - val_accuracy: 0.3198
# Epoch 4/60
# 359/359 [==============================] - 36s 100ms/step - loss: 6.5873 - accuracy: 0.2636 - val_loss: 5.7629 - val_accuracy: 0.3289
# Epoch 5/60
# 359/359 [==============================] - 35s 98ms/step - loss: 5.7125 - accuracy: 0.2851 - val_loss: 4.9006 - val_accuracy: 0.3834
# Epoch 6/60
# 359/359 [==============================] - 28s 78ms/step - loss: 4.9103 - accuracy: 0.3222 - val_loss: 4.4416 - val_accuracy: 0.3513
# Epoch 7/60
# 359/359 [==============================] - 29s 79ms/step - loss: 4.2356 - accuracy: 0.3554 - val_loss: 3.7489 - val_accuracy: 0.4155
# Epoch 8/60
# 359/359 [==============================] - 28s 77ms/step - loss: 3.7001 - accuracy: 0.3900 - val_loss: 3.1840 - val_accuracy: 0.4651
# Epoch 9/60
# 359/359 [==============================] - 29s 80ms/step - loss: 3.2442 - accuracy: 0.4049 - val_loss: 2.8185 - val_accuracy: 0.4797
# Epoch 10/60
# 359/359 [==============================] - 28s 78ms/step - loss: 2.8849 - accuracy: 0.4279 - val_loss: 2.5170 - val_accuracy: 0.5042
# Epoch 11/60
# 359/359 [==============================] - 28s 79ms/step - loss: 2.5982 - accuracy: 0.4491 - val_loss: 2.2731 - val_accuracy: 0.5203
# Epoch 12/60
# 359/359 [==============================] - 43s 119ms/step - loss: 2.3751 - accuracy: 0.4710 - val_loss: 2.1701 - val_accuracy: 0.5182
# Epoch 13/60
# 359/359 [==============================] - 27s 75ms/step - loss: 2.2164 - accuracy: 0.4773 - val_loss: 1.9844 - val_accuracy: 0.5489
# Epoch 14/60
# 359/359 [==============================] - 26s 73ms/step - loss: 2.0633 - accuracy: 0.4964 - val_loss: 1.8404 - val_accuracy: 0.5552
# Epoch 15/60
# 359/359 [==============================] - 27s 76ms/step - loss: 1.9518 - accuracy: 0.5146 - val_loss: 1.8420 - val_accuracy: 0.5649
# Epoch 16/60
# 359/359 [==============================] - 26s 73ms/step - loss: 1.8601 - accuracy: 0.5165 - val_loss: 1.6934 - val_accuracy: 0.5656
# Epoch 17/60
# 359/359 [==============================] - 28s 77ms/step - loss: 1.7777 - accuracy: 0.5330 - val_loss: 1.6343 - val_accuracy: 0.5810
# Epoch 18/60
# 359/359 [==============================] - 26s 73ms/step - loss: 1.7067 - accuracy: 0.5453 - val_loss: 1.5736 - val_accuracy: 0.5852
# Epoch 19/60
# 359/359 [==============================] - 28s 78ms/step - loss: 1.6680 - accuracy: 0.5434 - val_loss: 1.6903 - val_accuracy: 0.5531
# Epoch 20/60
# 359/359 [==============================] - 30s 84ms/step - loss: 1.6130 - accuracy: 0.5618 - val_loss: 1.5493 - val_accuracy: 0.5768
# Epoch 21/60
# 359/359 [==============================] - 27s 76ms/step - loss: 1.5815 - accuracy: 0.5660 - val_loss: 1.4772 - val_accuracy: 0.5964
# Epoch 22/60
# 359/359 [==============================] - 27s 76ms/step - loss: 1.5494 - accuracy: 0.5737 - val_loss: 1.4734 - val_accuracy: 0.6020
# Epoch 23/60
# 359/359 [==============================] - 27s 74ms/step - loss: 1.5210 - accuracy: 0.5789 - val_loss: 1.5039 - val_accuracy: 0.5936
# Epoch 24/60
# 359/359 [==============================] - 27s 75ms/step - loss: 1.5123 - accuracy: 0.5844 - val_loss: 1.4963 - val_accuracy: 0.5754
# Epoch 25/60
# 359/359 [==============================] - 28s 78ms/step - loss: 1.4941 - accuracy: 0.5856 - val_loss: 1.4533 - val_accuracy: 0.6061
# Epoch 26/60
# 359/359 [==============================] - 27s 76ms/step - loss: 1.4687 - accuracy: 0.5962 - val_loss: 1.4177 - val_accuracy: 0.6152
# Epoch 27/60
# 359/359 [==============================] - 26s 73ms/step - loss: 1.4619 - accuracy: 0.6005 - val_loss: 1.4363 - val_accuracy: 0.6194
# Epoch 28/60
# 359/359 [==============================] - 27s 76ms/step - loss: 1.4407 - accuracy: 0.6104 - val_loss: 1.4440 - val_accuracy: 0.6082
# Epoch 29/60
# 359/359 [==============================] - 26s 73ms/step - loss: 1.4430 - accuracy: 0.6061 - val_loss: 1.4724 - val_accuracy: 0.6131
# Epoch 30/60
# 359/359 [==============================] - 27s 75ms/step - loss: 1.4207 - accuracy: 0.6089 - val_loss: 1.4033 - val_accuracy: 0.6236
# Epoch 31/60
# 359/359 [==============================] - 26s 73ms/step - loss: 1.4095 - accuracy: 0.6120 - val_loss: 1.4311 - val_accuracy: 0.6061
# Epoch 32/60
# 359/359 [==============================] - 28s 77ms/step - loss: 1.4048 - accuracy: 0.6175 - val_loss: 1.3785 - val_accuracy: 0.6341
# Epoch 33/60
# 359/359 [==============================] - 27s 74ms/step - loss: 1.4047 - accuracy: 0.6166 - val_loss: 1.3838 - val_accuracy: 0.6348
# Epoch 34/60
# 359/359 [==============================] - 26s 73ms/step - loss: 1.3815 - accuracy: 0.6248 - val_loss: 1.4073 - val_accuracy: 0.6173
# Epoch 35/60
# 359/359 [==============================] - 26s 74ms/step - loss: 1.3866 - accuracy: 0.6269 - val_loss: 1.4059 - val_accuracy: 0.6110
# Epoch 36/60
# 359/359 [==============================] - 25s 70ms/step - loss: 1.3718 - accuracy: 0.6320 - val_loss: 1.3613 - val_accuracy: 0.6376
# Epoch 37/60
# 359/359 [==============================] - 27s 75ms/step - loss: 1.3835 - accuracy: 0.6286 - val_loss: 1.4049 - val_accuracy: 0.6131
# Epoch 38/60
# 359/359 [==============================] - 27s 75ms/step - loss: 1.3757 - accuracy: 0.6298 - val_loss: 1.3383 - val_accuracy: 0.6348
# Epoch 39/60
# 359/359 [==============================] - 27s 76ms/step - loss: 1.3497 - accuracy: 0.6418 - val_loss: 1.4327 - val_accuracy: 0.6082
# Epoch 40/60
# 359/359 [==============================] - 26s 73ms/step - loss: 1.3579 - accuracy: 0.6362 - val_loss: 1.3879 - val_accuracy: 0.6362
# Epoch 41/60
# 359/359 [==============================] - 29s 80ms/step - loss: 1.3549 - accuracy: 0.6421 - val_loss: 1.4252 - val_accuracy: 0.6138
# Epoch 42/60
# 359/359 [==============================] - 49s 137ms/step - loss: 1.3458 - accuracy: 0.6470 - val_loss: 1.3501 - val_accuracy: 0.6494
# Epoch 43/60
# 359/359 [==============================] - 71s 199ms/step - loss: 1.3529 - accuracy: 0.6418 - val_loss: 1.3716 - val_accuracy: 0.6564
# Epoch 44/60
# 359/359 [==============================] - 67s 186ms/step - loss: 1.3372 - accuracy: 0.6487 - val_loss: 1.3994 - val_accuracy: 0.6348
# Epoch 45/60
# 359/359 [==============================] - 45s 126ms/step - loss: 1.3398 - accuracy: 0.6512 - val_loss: 1.3822 - val_accuracy: 0.6369
# Epoch 46/60
# 359/359 [==============================] - 45s 124ms/step - loss: 1.3387 - accuracy: 0.6491 - val_loss: 1.3964 - val_accuracy: 0.6383
# Epoch 47/60
# 359/359 [==============================] - 46s 127ms/step - loss: 1.3385 - accuracy: 0.6518 - val_loss: 1.4099 - val_accuracy: 0.6355
# Epoch 48/60
# 359/359 [==============================] - 50s 139ms/step - loss: 1.3205 - accuracy: 0.6593 - val_loss: 1.3779 - val_accuracy: 0.6453
# Epoch 49/60
# 359/359 [==============================] - 43s 120ms/step - loss: 1.3368 - accuracy: 0.6570 - val_loss: 1.3761 - val_accuracy: 0.6529
# Epoch 50/60
# 359/359 [==============================] - 46s 129ms/step - loss: 1.3127 - accuracy: 0.6648 - val_loss: 1.4120 - val_accuracy: 0.6376
# Epoch 51/60
# 359/359 [==============================] - 46s 129ms/step - loss: 1.3267 - accuracy: 0.6606 - val_loss: 1.3905 - val_accuracy: 0.6459
# Epoch 52/60
# 359/359 [==============================] - 46s 129ms/step - loss: 1.3213 - accuracy: 0.6680 - val_loss: 1.4093 - val_accuracy: 0.6466
# Epoch 53/60
# 359/359 [==============================] - 45s 127ms/step - loss: 1.3250 - accuracy: 0.6600 - val_loss: 1.4239 - val_accuracy: 0.6313
# Epoch 54/60
# 359/359 [==============================] - 48s 133ms/step - loss: 1.3326 - accuracy: 0.6595 - val_loss: 1.3861 - val_accuracy: 0.6466
# Epoch 55/60
# 359/359 [==============================] - 46s 128ms/step - loss: 1.3149 - accuracy: 0.6741 - val_loss: 1.4116 - val_accuracy: 0.6397
# Epoch 56/60
# 359/359 [==============================] - 46s 127ms/step - loss: 1.3056 - accuracy: 0.6729 - val_loss: 1.4104 - val_accuracy: 0.6278
# Epoch 57/60
# 359/359 [==============================] - 47s 130ms/step - loss: 1.3121 - accuracy: 0.6709 - val_loss: 1.4269 - val_accuracy: 0.6620
# Epoch 58/60
# 359/359 [==============================] - 45s 125ms/step - loss: 1.3079 - accuracy: 0.6716 - val_loss: 1.4221 - val_accuracy: 0.6320
# Epoch 59/60
# 359/359 [==============================] - 45s 125ms/step - loss: 1.3091 - accuracy: 0.6709 - val_loss: 1.4352 - val_accuracy: 0.6432
# Epoch 60/60
# 359/359 [==============================] - 46s 129ms/step - loss: 1.3154 - accuracy: 0.6747 - val_loss: 1.4593 - val_accuracy: 0.6306

# %%
fig , ax = plt.subplots(1,2)
train_acc = history.history['accuracy']
train_loss = history.history['loss']
fig.set_size_inches(12,4)

ax[0].plot(history.history['accuracy'])
ax[0].plot(history.history['val_accuracy'])
ax[0].set_title('Training Accuracy vs Validation Accuracy')
ax[0].set_ylabel('Accuracy')
ax[0].set_xlabel('Epoch')
ax[0].legend(['Train', 'Validation'], loc='upper left')

ax[1].plot(history.history['loss'])
ax[1].plot(history.history['val_loss'])
ax[1].set_title('Training Loss vs Validation Loss')
ax[1].set_ylabel('Loss')
ax[1].set_xlabel('Epoch')
ax[1].legend(['Train', 'Validation'], loc='upper left')

plt.show()

# %%
model.save('model_optimal.h5')

# %%
img = image.load_img("../input/emotion-detection-fer/test/happy/im1021.png",target_size = (48,48),color_mode = "grayscale")
img = np.array(img)
plt.imshow(img)
print(img.shape)
# Out:
# (48, 48)

# %%
label_dict = {0:'Angry', 1:'Disgust', 2:'Fear', 3:'Happy', 4:'Neutral', 5:'Sad', 6:'Surprise'}

# %%
img = np.expand_dims(img,axis = 0)
img = img.reshape(1,48,48,1)
result = model.predict(img)
result = list(result[0])
print(result)
# Out:
# [1.0, 0.0, 0.0, 1.3614308e-38, 0.0, 0.0, 0.0]

# %%
img_index = result.index(max(result))
print(label_dict[img_index])
plt.show()
# Out:
# Angry

# %%
train_loss, train_acc = model.evaluate(train_generator)
test_loss, test_acc   = model.evaluate(validation_generator)
print("final train accuracy = {:.2f} , validation accuracy = {:.2f}".format(train_acc*100, test_acc*100))
# Out:
# 359/359 [==============================] - 45s 126ms/step - loss: 1.2116 - accuracy: 0.7108
# 23/23 [==============================] - 3s 116ms/step - loss: 1.4593 - accuracy: 0.6306
# final train accuracy = 71.08 , validation accuracy = 63.06

# %%
model.save_weights('model_weights.h5')
